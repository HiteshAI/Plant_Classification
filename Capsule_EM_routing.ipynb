# %% [markdown]
# <a href="https://colab.research.google.com/github/HiteshAI/Projects/blob/master/Capsule_EM_routing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /home
# !ls
# Out:
# /home

# %%
# !git clone https://github.com/YuxianMeng/Matrix-Capsules-pytorch
# Out:
# Cloning into 'Matrix-Capsules-pytorch'...
# remote: Enumerating objects: 157, done.
# remote: Total 157 (delta 0), reused 0 (delta 0), pack-reused 157
# Receiving objects: 100% (157/157), 46.71 KiB | 412.00 KiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
# %cd /home/Matrix-Capsules-pytorch/
# !ls
# Out:
# /home/Matrix-Capsules-pytorch
# Capsules.py  README.md	train.py  utils.py

# %%
# !python train.py -batch_size=64 -lr=2e-2 -num_epochs=5 -r=1 -print_freq=5
# Out:
# Streaming output truncated to the last 5000 lines.
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# batch:540, acc:62/64
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# batch:545, acc:64/64
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# batch:550, acc:64/64
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# batch:555, acc:62/64
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# batch:560, acc:62/64
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# batch:565, acc:60/64
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# ...
